# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudharsana125/ML-From-Scratch/blob/main/Day1_of_ML_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Machine Learning — Day 1

## Topics
- What is Machine Learning?
- Types of Machine Learning
- Features and Target
- Dataset
- Basic ML workflow

## Tools
- Python
- NumPy
- Pandas
- Scikit-learn
- Matplotlib

# %%
#Creating Dataframes
import pandas as pd
data = {
    "Hours studied": [1,2,3,4,5],
    "Exam results": [20,45,89,90,100]
}
df = pd.DataFrame(data)
df
# Out:
#    Hours studied  Exam results
# 0              1            20
# 1              2            45
# 2              3            89
# 3              4            90
# 4              5           100

# %%
df.head(3)
# Out:
#    Hours studied  Exam results
# 0              1            20
# 1              2            45
# 2              3            89

# %%
df.describe()
# Out:
#        Hours studied  Exam results
# count       5.000000      5.000000
# mean        3.000000     68.800000
# std         1.581139     34.564433
# min         1.000000     20.000000
# 25%         2.000000     45.000000
# 50%         3.000000     89.000000
# 75%         4.000000     90.000000
# max         5.000000    100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hours studied  5 non-null      int64
#  1   Exam results   5 non-null      int64
# dtypes: int64(2)
# memory usage: 212.0 bytes

# %%
import matplotlib.pyplot as plt
plt.scatter(df["Hours studied"], df["Exam results"])
plt.xlabel("Hours studied")
plt.ylabel("Exam results")
plt.show()

# %%
x = df["Hours studied"]
y = df["Exam results"]
print("Feature: ")
print(x)
print("Target: ")
print(y)
# Out:
# Feature:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Hours studied, dtype: int64
# Target:
# 0     20
# 1     45
# 2     89
# 3     90
# 4    100
# Name: Exam results, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print("x_train:")
print(x_train)
print("x_test:")
print(x_test)
print("y_train:")
print(y_train)
print("y_test:")
print(y_test )
# Out:
# x_train:
# 4    5
# 2    3
# 0    1
# 3    4
# Name: Hours studied, dtype: int64
# x_test:
# 1    2
# Name: Hours studied, dtype: int64
# y_train:
# 4    100
# 2     89
# 0     20
# 3     90
# Name: Exam results, dtype: int64
# y_test:
# 1    45
# Name: Exam results, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train.values.reshape(-1,1), y_train)
# Out:
# LinearRegression()
